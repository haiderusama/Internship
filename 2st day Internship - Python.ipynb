# %% [markdown]
# #List
# things are in order
# #Dictonaries
# key-value pair

# %%
Usama_Friend = dict()
Usama_Friend["Web Developer"] = "Anas"
Usama_Friend["React Developer"] = "Hamza"
Usama_Friend["ALL Rounder"] = "Wasi Ur Rehman Qamar"
Usama_Friend["Total"] = 3
print(Usama_Friend)
Usama_Friend["Total"] = Usama_Friend["Total"] - 2
print(Usama_Friend)
# Out:
# {'Web Developer': 'Anas', 'React Developer': 'Hamza', 'ALL Rounder': 'Wasi Ur Rehman Qamar', 'Total': 3}
# {'Web Developer': 'Anas', 'React Developer': 'Hamza', 'ALL Rounder': 'Wasi Ur Rehman Qamar', 'Total': 1}

# %%
counts = dict()
names = ["Usama" , "Wasi Ur Rehman Qamar", "Anas" , "Hamza Masood", "Saad", "Mudasir", "Shazaib Butt", "Husnain Urf HR Jan", "Wasi", "Wasi Ur Rehman Qamar", "Mudasir", "Shazaib Butt"]
for name in names:
  if name not in counts:
    counts[name] = 1
  else:
    counts[name] = counts[name] + 1
print(counts)
# Out:
# {'Usama': 1, 'Wasi Ur Rehman Qamar': 2, 'Anas': 1, 'Hamza Masood': 1, 'Saad': 1, 'Mudasir': 2, 'Shazaib Butt': 2, 'Husnain Urf HR Jan': 1, 'Wasi': 1}

# %%
counts = dict()
names = ["Usama" , "Wasi Ur Rehman Qamar", "Anas" , "Hamza Masood", "Saad", "Mudasir", "Shazaib Butt", "Husnain Urf HR Jan", "Wasi", "Wasi Ur Rehman Qamar", "Mudasir", "Shazaib Butt"]
for name in names:
  counts[name] = counts.get(name , 0) + 1
print(counts)
# Out:
# {'Usama': 1, 'Wasi Ur Rehman Qamar': 2, 'Anas': 1, 'Hamza Masood': 1, 'Saad': 1, 'Mudasir': 2, 'Shazaib Butt': 2, 'Husnain Urf HR Jan': 1, 'Wasi': 1}

# %%
counts = {'Usama': 1, 'Wasi Ur Rehman Qamar': 2, 'Anas': 1, 'Hamza Masood': 1, 'Saad': 1, 'Mudasir': 2, 'Shazaib Butt': 2, 'Husnain Urf HR Jan': 1, 'Wasi': 1}
for key in counts:
  print(key , counts[key])
# Out:
# Usama 1
# Wasi Ur Rehman Qamar 2
# Anas 1
# Hamza Masood 1
# Saad 1
# Mudasir 2
# Shazaib Butt 2
# Husnain Urf HR Jan 1
# Wasi 1

# %%
counts = {'Usama': 1, 'Wasi Ur Rehman Qamar': 2, 'Anas': 1, 'Hamza Masood': 1, 'Saad': 1, 'Mudasir': 2, 'Shazaib Butt': 2, 'Husnain Urf HR Jan': 1, 'Wasi': 1}
print(counts.keys())
print(counts.values())
print(counts.items())
# Out:
# dict_keys(['Usama', 'Wasi Ur Rehman Qamar', 'Anas', 'Hamza Masood', 'Saad', 'Mudasir', 'Shazaib Butt', 'Husnain Urf HR Jan', 'Wasi'])
# dict_values([1, 2, 1, 1, 1, 2, 2, 1, 1])
# dict_items([('Usama', 1), ('Wasi Ur Rehman Qamar', 2), ('Anas', 1), ('Hamza Masood', 1), ('Saad', 1), ('Mudasir', 2), ('Shazaib Butt', 2), ('Husnain Urf HR Jan', 1), ('Wasi', 1)])

# %%
Name = "Usama Haider ali imran malhi ali irfan malhi wasi rehman qamar ali haider Anas hamza masood mudasir\n  malhi wasi rehman qamar ali haider Anas hamza masood mudasir "
count = dict()
lines = Name.split(" ")
for line in lines:
    count[line] = count.get(line,0) + 1
print(count)

bigword = None
bigcount = None
for word, count in count.items():
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count

print(bigword, bigcount)
# Out:
# {'Usama': 1, 'Haider': 1, 'ali': 4, 'imran': 1, 'malhi': 3, 'irfan': 1, 'wasi': 2, 'rehman': 2, 'qamar': 2, 'haider': 2, 'Anas': 2, 'hamza': 2, 'masood': 2, 'mudasir\n': 1, '': 2, 'mudasir': 1}
# ali 4

# %%
stuff = dict()
print(stuff.get('candy',-1))
# Out:
# -1

# %% [markdown]
# Tuples

# %%
Friends_Name = ('Wasi', 'HR', 'Anas', 'Hamza')
print(Friends_Name)
print(Friends_Name[3])
for iter in Friends_Name:
  print(iter)
# Out:
# ('Wasi', 'HR', 'Anas', 'Hamza')
# Hamza
# Wasi
# HR
# Anas
# Hamza

# %% [markdown]
# Tuples and Strings are not immutable

# %%
type_of_friends_in_tuple = tuple()
dir(type_of_friends_in_tuple)
type_of_friends_in_list = list()
dir(type_of_friends_in_list)
type_of_friends_in_dict = dict()
dir(type_of_friends_in_dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
(Wasi , Hr , Anas , Hamza)=(1,2,3,4)
print(Wasi)
# Out:
# 1

# %%
("wasi") > ("Every Student in Class")
# Out:
# True

# %%
("A") > ("W")
# Out:
# False

# %%
("Anas") > ("Wasi")
# Out:
# False

# %%
c = {'b':10 , 'a':11}
tmp =list()
for k,v in c.items():
  tmp.append((v,k))
print(tmp)
tmp = sorted(tmp, reverse=True)
print(tmp)
# Out:
# [(10, 'b'), (11, 'a')]
# [(11, 'a'), (10, 'b')]

# %%
x,y = 3,4
print(y)
# Out:
# 4

# %%
Days = ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')
print(Days[2])
# Out:
# Wed

# %% [markdown]
# New Course of Python for everyone is started

# %% [markdown]
# Regular Experssions

# %%
import re
pattern = r"[a-z]ext"
text = '''From Wikipedia, the free encyclopedia
Various examples of text in different languages
In literary theory, a text is any object that can be "read", whether this object is a work of literature, a street sign, an arrangement of buildings on a city block, or styles of clothing. It is a coherent set of signs that transmits some kind of informative message.[1] This set of signs is considered in terms of the informative message's content, rather than in terms of its physical form or the medium in which it is represented.
Within the field of literary criticism, "text" also refers to the original information content of a particular piece of writing; that is, the "text" of a work is that primal symbolic arrangement of letters as originally composed, apart from later alterations, deterioration, commentary, translations, paratext, etc. Therefore, when literary criticism is concerned with the determination of a "text", it is concerned with the distinguishing of the original information content from whatever has been added to or subtracted from that content as it appears in a given textual document (that is, a physical representation of text).
Since the history of writing predates the concept of the "text", most texts were not written with this concept in mind. Most written works fall within a narrow range of the types described by text theory. The concept of "text" becomes relevant if and when a "coherent written message is completed and needs to be referred to independently of the circumstances in which it was created."[citation needed]'''
matches = re.finditer(pattern, text)
for match in matches:
  print(match.span())
print(type(match.span()))
print(text[match.span()[0]:match.span()[1]])
# Out:
# (58, 62)
# (108, 112)
# (561, 565)
# (663, 667)
# (825, 829)
# (913, 917)
# (1085, 1089)
# (1141, 1145)
# (1206, 1210)
# (1218, 1222)
# (1340, 1344)
# (1369, 1373)
# <class 'tuple'>
# text

# %%
import re
text = "From haiderusama@hotmail.com to wasiurrehmanqamar@gmail.com"
match = re.findall('^From (\S+@\S+)', text)
print(match)
# Out:
# ['haiderusama@hotmail.com']

# %%
import re
text = "From haiderusama@hotmail.com to wasiurrehmanqamar@gmail.com"
words = text.split()
print(words)
email = words[1]
print(email)
ans = email.split('@')
print(ans)
print(ans[1])

#with regular expression
y= re.findall( "@([^ ]*)" , text)
print(y)
# Out:
# ['From', 'haiderusama@hotmail.com', 'to', 'wasiurrehmanqamar@gmail.com']
# haiderusama@hotmail.com
# ['haiderusama', 'hotmail.com']
# hotmail.com
# ['hotmail.com', 'gmail.com']

# %% [markdown]
# ^
#
# Matches the beginning of a line
#
# $
#
# Matches the end of the line
#
# .
#
# Matches any character
#
# \s
#
# Matches whitespace
#
# \S
#
# Matches any non-whitespace character
#
# *
#
# Repeats a character zero or more times
#
# *?
#
# Repeats a character zero or more times (non-greedy)
#
# +
#
# Repeats a character one or more times
#
# +?
#
# Repeats a character one or more times (non-greedy)
#
# [aeiou]
#
# Matches a single character in the listed set
#
# [^XYZ]
#
# Matches a single character not in the listed set
#
# [a-z0-9]
#
# The set of characters can include a range
#
# (
#
# Indicates where string extraction is to start
#
# )
#
# Indicates where string extraction is to end
